# %%
# %sql

DROP TABLE IF EXISTS metadata_etl.default.bronze_customer;
DROP TABLE IF EXISTS metadata_etl.default.silver_customer;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_customeraddress;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_customer;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_address;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_productcategory;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_product;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_order_fact;

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_product_dim

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.bronze_salesorderheader

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_productcategory

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_salesorderdetail

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_salesorderheader

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_customeraddress

# %%
# %sql
DROP TABLE IF EXISTS metadata_etl.default.silver_customer_address
